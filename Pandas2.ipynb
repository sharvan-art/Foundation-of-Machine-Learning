# %%
# The Scenario: TechCorp HR Data
# Context: You are an HR analyst for "TechCorp". You have been provided with a DataFrame named df containing employee records.
# The DataFrame df has the following columns:
# Name: The employee's name (contains some missing values)
# Department: The department they works in (e.g., 'IT','Sales','HR')
# Role: Their job title (e.g., 'Analyst','Manager','Developer')
# Experience: Years of experience (contains some missing values)
# Salary: Annual salary in USD (contains some missing values)
# Score: Most recent performance review score (contains some missing values for new hires)
# Note: Assume the DataFrame df is already loaded in your Python environment.

import pandas as pd
import numpy as np

# Create HR Data
data = {
    "Name": ["Aman", "Saurav", "Karan", "Shubham", "Abhishek",
             "Neha", "Riya", None, "Vikram", "Anjali"],
    
    "Department": ["IT", "Sales", "IT", "HR", "IT",
                   "Sales", "HR", "IT", "Sales", "HR"],
    
    "Role": ["Developer", "Manager", "Analyst", "Manager", "Developer",
             "Executive", "Recruiter", "Developer", "Executive", "Analyst"],
    
    "Experience": [3, 7, 5, np.nan, 2,
                   6, 4, 1, np.nan, 3],
    
    "Salary": [60000, 90000, 75000, 85000, np.nan,
               65000, 70000, 55000, 62000, np.nan],
    
    "Score": [4.2, 4.8, 4.0, 4.5, np.nan,
              4.1, 3.9, np.nan, 4.3, 4.0]
}

df = pd.DataFrame(data)

print("Original HR Dataset:")
print(df)
# Out:
# Original HR Dataset:
#        Name Department       Role  Experience   Salary  Score
# 0      Aman         IT  Developer         3.0  60000.0    4.2
# 1    Saurav      Sales    Manager         7.0  90000.0    4.8
# 2     Karan         IT    Analyst         5.0  75000.0    4.0
# 3   Shubham         HR    Manager         NaN  85000.0    4.5
# 4  Abhishek         IT  Developer         2.0      NaN    NaN
# 5      Neha      Sales  Executive         6.0  65000.0    4.1
# 6      Riya         HR  Recruiter         4.0  70000.0    3.9
# 7       NaN         IT  Developer         1.0  55000.0    NaN
# 8    Vikram      Sales  Executive         NaN  62000.0    4.3
# 9    Anjali         HR    Analyst         3.0      NaN    4.0

# %%
# Write the exact Pandas code to answer the following questions:
# Basic Averages:
# 1. What is the average (mean) salary for each department?
# 2. What is the average (mean) Performance Score for each role?
# Counting and Sizing:
# 3. How many actual, non-null Performance Score entries exist for each Department?
# 4. What is the total number of employees records (rows) in each Datapartment, regardless of wheter data is missing?

# %%
# Exercise Questions-Part 2
# Multiple Aggregations:
# 5. Generate a summary table for salary based on Department that includes the mean, maximum, minimum, and count in a single line of code.
# 6. Generate the same summary table (mean, max, min, count) but analyze the Performance Score based on Role of Department.
# Grouping by Multiple Columns:
# 7. Find the average salary grouped by both Department and Role.
# 8. Find the average Performance Score grouped by both Department and Experience level.
